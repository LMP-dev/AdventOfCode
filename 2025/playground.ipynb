# %%
l = ["11-22,95-115,998-1012"]

# %%
range_list = l[0].split(",")
print(range_list)
[tuple(item.split("-")) for item in range_list]
# Out:
# [('11', '22'), ('95', '115'), ('998', '1012')]

# %%
n = 999000
s = str(n)

m, r = divmod(len(s), 2)

print(s[:m])
print(s[m:])
# Out:
# 999
# 000
